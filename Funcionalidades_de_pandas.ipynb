# %% [markdown]
# <a href="https://colab.research.google.com/github/avanegasp/Google_Colab/blob/main/Funcionalidades_de_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_books = pd.read_csv('/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6 (1).csv', sep=',',header=0)

df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
df_astop = pd.read_csv('/content/Aspirantes TOP - Limpio - Todo.csv', sep=',',header=0)

df_astop.head(2)
# Out:
#                            Correo                            Nombre  Género  \
# 0  alexanderbohorquez96@gmail.com  Brayan Alexander Bohorquez ramos    Male
# 1        kte.vargas1102@gmail.com           Katerine Vargas Ramirez  Female
#
#   País  Edad  Nivel  Misiones Agendó con Mentor técnico         Ment@r  \
# 0   CO    27      1         0                       NaN  Ferney Medina
# 1   CO    28      1         0                       NaN  Ferney Medina
#
#    Perfilación  Prueba Técnica Tipo de contrato - modalidad Resultado PT  \
# 0        False           False                          NaN          NaN
# 1        False           False                          NaN          NaN
#
#   Sigue en el Proceso
# 0                 NaN
# 1                 NaN

# %%
df_astop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Correo                        178 non-null    object
#  1   Nombre                        178 non-null    object
#  2   Género                        178 non-null    object
#  3   País                          178 non-null    object
#  4   Edad                          178 non-null    int64
#  5   Nivel                         178 non-null    int64
#  6   Misiones                      178 non-null    int64
#  7   Agendó con Mentor técnico     81 non-null     object
#  8   Ment@r                        178 non-null    object
#  9   Perfilación                   178 non-null    bool
#  10  Prueba Técnica                178 non-null    bool
#  11  Tipo de contrato - modalidad  110 non-null    object
# ...

# %%
df_astop.describe()
# Out:
#              Edad       Nivel    Misiones
# count  178.000000  178.000000  178.000000
# mean    31.410112    1.640449    5.938202
# std      7.058697    0.624313    4.033980
# min     19.000000    1.000000    0.000000
# 25%     27.000000    1.000000    1.000000
# 50%     30.000000    2.000000    7.000000
# 75%     36.000000    2.000000    9.000000
# max     51.000000    3.000000   13.000000

# %% [markdown]
# ## Tail devuelve los 2 últimos

# %%
df_astop.tail(2)
# Out:
#                        Correo                      Nombre Género País  Edad  \
# 176    juanalbadan3@gmail.com  Juan David Albadan alvarez   Male   CO    34
# 177  juancrivas2179@gmail.com                  Juan Rivas   Male   CO    26
#
#      Nivel  Misiones Agendó con Mentor técnico                Ment@r  \
# 176      3         6           Leonel Oliveros  Luis David Hernandez
# 177      2         8           Cristian Moreno           Juan Quiroz
#
#      Perfilación  Prueba Técnica Tipo de contrato - modalidad Resultado PT  \
# 176         True           False                     ISA - TC          NaN
# 177         True            True                     ISA - TC           c1
#
#     Sigue en el Proceso
# 176                 NaN
# 177   Falta Experiencia

# %%
df_astop.tail(2)
# Out:
#                        Correo                      Nombre Género País  Edad  \
# 176    juanalbadan3@gmail.com  Juan David Albadan alvarez   Male   CO    34
# 177  juancrivas2179@gmail.com                  Juan Rivas   Male   CO    26
#
#      Nivel  Misiones Agendó con Mentor técnico                Ment@r  \
# 176      3         6           Leonel Oliveros  Luis David Hernandez
# 177      2         8           Cristian Moreno           Juan Quiroz
#
#      Perfilación  Prueba Técnica Tipo de contrato - modalidad Resultado PT  \
# 176         True           False                     ISA - TC          NaN
# 177         True            True                     ISA - TC           c1
#
#     Sigue en el Proceso
# 176                 NaN
# 177   Falta Experiencia

# %%
df_astop.memory_usage(deep=True)
# Out:
# Index                             128
# Correo                          14322
# Nombre                          15088
# Género                          10931
# País                            10502
# Edad                             1424
# Nivel                            1424
# Misiones                         1424
# Agendó con Mentor técnico        9146
# Ment@r                          13634
# Perfilación                       178
# Prueba Técnica                    178
# Tipo de contrato - modalidad     9500
# Resultado PT                     7370
# Sigue en el Proceso              8495
# dtype: int64

# %% [markdown]
# ## Value_counts hace las evaluación de valores únicos

# %%
df_astop['Género'].value_counts()
# Out:
# Male      139
# Female     34
# LGTB+       5
# Name: Género, dtype: int64

# %%
df_astop['Nivel'].value_counts()
# Out:
# 2    86
# 1    78
# 3    14
# Name: Nivel, dtype: int64

# %% [markdown]
# ## drop_duplicates elimina duplicados

# %%
df_astop.drop_duplicates()

# %% [markdown]
# ## deja el último duplicado

# %%
df_astop.drop_duplicates(keep='last')

# %% [markdown]
# ## ordena los valores por el valor que le pases

# %%
df_astop=df_astop.head(10)
df_astop
# Out:
#                            Correo                               Nombre  \
# 0  alexanderbohorquez96@gmail.com     Brayan Alexander Bohorquez ramos
# 1        kte.vargas1102@gmail.com              Katerine Vargas Ramirez
# 2              penta29@hotmail.es                 Lugui Pedro Lazo Coz
# 3              robedw20@gmail.com                    Edward Bustamante
# 4            nohemi.ldr@gmail.com                      Nohemi Martinez
# 5                jmerkv@gmail.com       Juan Miguel Mercado Villadiego
# 6               kavajue@gmail.com  Cristhian Eduardo Velázquez Coronel
# 7     jsolareshernandez@gmail.com                         Jose Solares
# 8  lucciana.chambilla@utec.edu.pe     Lucciana Débora Chambilla Mamani
# 9        locky_mbsces@hotmail.com                  Hector Soto Mendoza
#
#    Género País  Edad  Nivel  Misiones Agendó con Mentor técnico  \
# 0    Male   CO    27      1         0                       NaN
# ...

# %%
df_astop.sort_values('Misiones',ascending=True)
# Out:
#                            Correo                               Nombre  \
# 0  alexanderbohorquez96@gmail.com     Brayan Alexander Bohorquez ramos
# 1        kte.vargas1102@gmail.com              Katerine Vargas Ramirez
# 2              penta29@hotmail.es                 Lugui Pedro Lazo Coz
# 4            nohemi.ldr@gmail.com                      Nohemi Martinez
# 5                jmerkv@gmail.com       Juan Miguel Mercado Villadiego
# 6               kavajue@gmail.com  Cristhian Eduardo Velázquez Coronel
# 8  lucciana.chambilla@utec.edu.pe     Lucciana Débora Chambilla Mamani
# 3              robedw20@gmail.com                    Edward Bustamante
# 7     jsolareshernandez@gmail.com                         Jose Solares
# 9        locky_mbsces@hotmail.com                  Hector Soto Mendoza
#
#    Género País  Edad  Nivel  Misiones Agendó con Mentor técnico  \
# 0    Male   CO    27      1         0                       NaN
# ...
