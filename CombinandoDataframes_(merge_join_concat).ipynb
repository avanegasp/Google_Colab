# %% [markdown]
# <a href="https://colab.research.google.com/github/avanegasp/Google_Colab/blob/main/CombinandoDataframes_(merge_join_concat).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_astop = pd.read_csv('/content/Aspirantes TOP - Limpio - Todo.csv', sep=',',header=0)

df_astop.head(2)
# Out:
#                            Correo                            Nombre  Género  \
# 0  alexanderbohorquez96@gmail.com  Brayan Alexander Bohorquez ramos    Male
# 1        kte.vargas1102@gmail.com           Katerine Vargas Ramirez  Female
#
#   País  Edad  Nivel  Misiones Agendó con Mentor técnico         Ment@r  \
# 0   CO    27      1         0                       NaN  Ferney Medina
# 1   CO    28      1         0                       NaN  Ferney Medina
#
#    Perfilación  Prueba Técnica Tipo de contrato - modalidad Resultado PT  \
# 0        False           False                          NaN          NaN
# 1        False           False                          NaN          NaN
#
#   Sigue en el Proceso
# 0                 NaN
# 1                 NaN

# %%
c9_astop = pd.read_csv('/content/C9 - Curso Aspirante y Admitidos - 25 de abril - toda.csv',sep=',',header=0)
c9_astop.head(2)
# Out:
#       id                       email  first_name       last_name country  \
# 0  12392    20182001tiempo@gmail.com  luz karina   ccalla mestas      PE
# 1  12176  alexjesus-4856@hotmail.com      Alexis  Buelvas Madera      CO
#
#    status  género fecha nacimiento  edad  Nivel  \
# 0      15  Female       2001-01-28    22      1
# 1      14    male       1992-10-28    31      1
#
#                                                 info
# 0  {birthday=2001-01-28, aspiring_course_accepted...
# 1  {birthday=1992-10-28, uid=a0ec285a, goal=Quier...

# %%
c9_astop.describe()
# Out:
#                  id      status        edad       Nivel
# count    759.000000  759.000000  759.000000  759.000000
# mean   12458.337286   14.503294   30.272727    2.276680
# std      267.917956    0.728013    6.784522    0.557862
# min    12015.000000    4.000000   12.000000    1.000000
# 25%    12215.500000   14.000000   25.000000    2.000000
# 50%    12446.000000   15.000000   30.000000    2.000000
# 75%    12671.000000   15.000000   35.000000    3.000000
# max    12954.000000   15.000000   61.000000    3.000000

# %%
c9_astop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 759 entries, 0 to 758
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                759 non-null    int64
#  1   email             759 non-null    object
#  2   first_name        759 non-null    object
#  3   last_name         759 non-null    object
#  4   country           759 non-null    object
#  5   status            759 non-null    int64
#  6   género            759 non-null    object
#  7   fecha nacimiento  759 non-null    object
#  8   edad              759 non-null    int64
#  9   Nivel             759 non-null    int64
#  10  info              759 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 65.4+ KB

# %%
new_c9= c9_astop.drop('fecha nacimiento',axis=1)
new_c9
# Out:
#         id                       email         first_name       last_name  \
# 0    12392    20182001tiempo@gmail.com         luz karina   ccalla mestas
# 1    12176  alexjesus-4856@hotmail.com             Alexis  Buelvas Madera
# 2    12064    amethgabriel@hotmail.com              Ameth         Ordoñez
# 3    12580        angieanais@gmail.com        Angie Anais  Tejada Velarde
# 4    12440       aromero4@eafit.edu.co     Alejandro luis     Romero Díaz
# ..     ...                         ...                ...             ...
# 754  12679     Yeisson_250@hotmail.com   Yeisson fabricio   Parga salazar
# 755  12797    yennyrey222010@gmail.com              Yenny             Rey
# 756  12202         yolka.erc@gmail.com              Yolka            Rios
# 757  12359          yubretzy@gmail.com  Yubretzy Josefina     Mata Aguana
# 758  12593       yulianicm@hotmail.com            Yuliani        Castilla
#
#     country  status  género  edad  Nivel  \
# ...

# %%
new_c9= new_c9.drop('status',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-6717034f3ce6> in <cell line: 1>()
# ----> 1 new_c9= new_c9.drop('status',axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
new_c9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 759 entries, 0 to 758
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          759 non-null    int64
#  1   email       759 non-null    object
#  2   first_name  759 non-null    object
#  3   last_name   759 non-null    object
#  4   country     759 non-null    object
#  5   género      759 non-null    object
#  6   edad        759 non-null    int64
#  7   Nivel       759 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 47.6+ KB

# %%
new_c9=new_c9.drop('id',axis=1)

# %%
new_c9.mean()
# Out:
# <ipython-input-27-92d22f3205f5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_c9.mean()
# edad     30.272727
# Nivel     2.276680
# dtype: float64

# %%
new_c9.head(2)
# Out:
#                         email  first_name       last_name country  género  \
# 0    20182001tiempo@gmail.com  luz karina   ccalla mestas      PE  Female
# 1  alexjesus-4856@hotmail.com      Alexis  Buelvas Madera      CO    male
#
#    edad  Nivel
# 0    22      1
# 1    31      1

# %%
df_astop.head(2)
# Out:
#                            Correo                            Nombre  Género  \
# 0  alexanderbohorquez96@gmail.com  Brayan Alexander Bohorquez ramos    Male
# 1        kte.vargas1102@gmail.com           Katerine Vargas Ramirez  Female
#
#   País  Edad  Nivel  Misiones Agendó con Mentor técnico         Ment@r  \
# 0   CO    27      1         0                       NaN  Ferney Medina
# 1   CO    28      1         0                       NaN  Ferney Medina
#
#    Perfilación  Prueba Técnica Tipo de contrato - modalidad Resultado PT  \
# 0        False           False                          NaN          NaN
# 1        False           False                          NaN          NaN
#
#   Sigue en el Proceso
# 0                 NaN
# 1                 NaN

# %%
pd.concat([new_c9, df_astop])
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py:700: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# /usr/local/lib/python3.10/dist-packages/google/colab/_interactive_table_hint_button.py:162: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_html=dataframe._repr_html_(),
#                           email      first_name       last_name country  \
# 0      20182001tiempo@gmail.com      luz karina   ccalla mestas      PE
# 1    alexjesus-4856@hotmail.com          Alexis  Buelvas Madera      CO
# 2      amethgabriel@hotmail.com           Ameth         Ordoñez      CO
# 3          angieanais@gmail.com     Angie Anais  Tejada Velarde      PE
# ...

# %%
pd.concat([new_c9, df_astop]).head(10)
# Out:
#                          email      first_name         last_name country  \
# 0     20182001tiempo@gmail.com      luz karina     ccalla mestas      PE
# 1   alexjesus-4856@hotmail.com          Alexis    Buelvas Madera      CO
# 2     amethgabriel@hotmail.com           Ameth           Ordoñez      CO
# 3         angieanais@gmail.com     Angie Anais    Tejada Velarde      PE
# 4        aromero4@eafit.edu.co  Alejandro luis       Romero Díaz      CO
# 5         borgesmj19@gmail.com          Miguel            Borges      CO
# 6    camilo.suarez85@gmail.com   Brayan Camilo     Suarez Cortes      CO
# 7         carlososoa@gmail.com   carlos andres    osorio agudelo      CO
# 8  Cesar.palaciosing@gmail.com   Cesar augisto  Rosales palacios      CO
# 9      cristianxrost@gmail.com        Cristian            Rosero      CO
#
#    género  edad  Nivel Correo Nombre Género País  Edad  Misiones  \
# 0  Female  22.0      1    NaN    NaN    NaN  NaN   NaN       NaN
# ...

# %%
pd.concat([new_c9, df_astop],ignore_index=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py:700: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# /usr/local/lib/python3.10/dist-packages/google/colab/_interactive_table_hint_button.py:162: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_html=dataframe._repr_html_(),
#                           email      first_name       last_name country  \
# 0      20182001tiempo@gmail.com      luz karina   ccalla mestas      PE
# 1    alexjesus-4856@hotmail.com          Alexis  Buelvas Madera      CO
# 2      amethgabriel@hotmail.com           Ameth         Ordoñez      CO
# 3          angieanais@gmail.com     Angie Anais  Tejada Velarde      PE
# ...

# %%
pd.concat([new_c9, df_astop],axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py:700: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# /usr/local/lib/python3.10/dist-packages/google/colab/_interactive_table_hint_button.py:162: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_html=dataframe._repr_html_(),
#                           email         first_name       last_name country  \
# 0      20182001tiempo@gmail.com         luz karina   ccalla mestas      PE
# 1    alexjesus-4856@hotmail.com             Alexis  Buelvas Madera      CO
# 2      amethgabriel@hotmail.com              Ameth         Ordoñez      CO
# 3          angieanais@gmail.com        Angie Anais  Tejada Velarde      PE
# ...

# %% [markdown]
# ## merge

# %%
df_astop.merge(new_c9).head(2)
# Out:
#                            Correo                            Nombre Género  \
# 0  alexanderbohorquez96@gmail.com  Brayan Alexander Bohorquez ramos   Male
# 1  alexanderbohorquez96@gmail.com  Brayan Alexander Bohorquez ramos   Male
#
#   País  Edad  Nivel  Misiones Agendó con Mentor técnico         Ment@r  \
# 0   CO    27      1         0                       NaN  Ferney Medina
# 1   CO    27      1         0                       NaN  Ferney Medina
#
#    Perfilación  Prueba Técnica Tipo de contrato - modalidad Resultado PT  \
# 0        False           False                          NaN          NaN
# 1        False           False                          NaN          NaN
#
#   Sigue en el Proceso                       email  first_name       last_name  \
# 0                 NaN    20182001tiempo@gmail.com  luz karina   ccalla mestas
# 1                 NaN  alexjesus-4856@hotmail.com      Alexis  Buelvas Madera
#
#   country  género  edad
# 0      PE  Female    22
# ...

# %% [markdown]
# ## Hice merge uniendo las tablas con las llave edad que cada una de ellas comparte, fíjate que una esta en minúscula(edad) y la otra en mayúscula (Edad)

# %%
df_astop.merge(new_c9, left_on='Edad', right_on='edad').head(2)
# Out:
#                            Correo                            Nombre Género  \
# 0  alexanderbohorquez96@gmail.com  Brayan Alexander Bohorquez ramos   Male
# 1  alexanderbohorquez96@gmail.com  Brayan Alexander Bohorquez ramos   Male
#
#   País  Edad  Nivel_x  Misiones Agendó con Mentor técnico         Ment@r  \
# 0   CO    27        1         0                       NaN  Ferney Medina
# 1   CO    27        1         0                       NaN  Ferney Medina
#
#    Perfilación  ...  Tipo de contrato - modalidad Resultado PT  \
# 0        False  ...                           NaN          NaN
# 1        False  ...                           NaN          NaN
#
#   Sigue en el Proceso                             email first_name  \
# 0                 NaN              pj_13_96@hotmail.com      Pablo
# 1                 NaN  alejandramunozvelosa23@gmail.com  Alejandra
#
#          last_name country  género edad  Nivel_y
# 0  Galarza Rosales      PE    male   27        1
# ...

# %% [markdown]
# ## JOIN (INDEX MATCH)

# %%
df_astop.join(new_c9).head(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-73160437dc05> in <cell line: 1>()
# ----> 1 df_astop.join(new_c9).head(2)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9977         5  K1  A5   B1
#    9978         """
# -> 9979         return self._join_compat(
#    9980             other,
#    9981             on=on,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10016                     validate=validate,
#   10017                 )
# > 10018             return merge(
#   10019                 self,
#   10020                 other,
#
# ...
